# %% [markdown]
# # Agent for recipe cooking - Initial Performance Review

# %% [markdown]
# ## Objective
#
# We want to get an initial idea for what's possible and not possible.
#
# Our initial idea is to create a recipe cooking agent that can guide a user through the process of cooking a recipe.
#
# Before illustrating how a session might look like, we need to understand how recipe data is structured.
#
# ## Summary of results
#
# Given an initial system prompt with little tuning, we were able to get the agent working as intented on a subset of the test recipes.
#
# i.e. Start with preparing ingredients, then move on to cooking the recipe.
#
# However, a major flaw was that the agent was unable to reliably terminate the session after the recipe is complete.
#
# This will need to be addressed properly in a follow up iteration.

# %% [markdown]
# ## Recipe Data Structure
#
# The `recipe_scrapers` package is able to return a `AbstractScraper` object, which given a URl, will return structured data about the recipe.

# %% [markdown]
# Given a list of URLs to test on, we can get a list of `AbstractScraper` objects.

# %%
from recipe_scrapers import scrape_me

test_urls = [
    "https://www.allrecipes.com/recipe/158968/spinach-and-feta-turkey-burgers/",
    "https://www.allrecipes.com/recipe/93037/fresh-cranberry-salsa/",
    "https://www.bbcgoodfood.com/recipes/spicy-chickpea-stew",
    "https://www.bbcgoodfood.com/recipes/oven-baked-risotto",
    "https://www.bbcgoodfood.com/recipes/veggie-shepherds-pie-sweet-potato-mash",
    "https://www.allrecipes.com/recipe/157940/outrageous-warm-chicken-nacho-dip/",
    "https://dinnerthendessert.com/pork-dim-sum-recipe/",
    "https://www.hellofresh.com/recipes/fuego-chicken-fajita-tacos-68c7e2b837c1ef9942a55306"
]

recipes = [scrape_me(url) for url in test_urls]

# %% [markdown]
# We are interested (for now), in the following methods:

# %%
recipes[2].ingredients()
# Out:
# ['1 tbsp rapeseed oil',
#  '2 onions (320g), roughly chopped',
#  '2 green peppers deseeded and cut into cubes',
#  '2 tsp hot chilli powder',
#  '1 tbsp ground coriander',
#  '1 tsp ground cumin',
#  '500ml carton passata',
#  '2 x 400g cans chickpeas',
#  '2 tsp vegetable bouillon powder',
#  '40g flame raisins',
#  '½ lemon juiced, flesh scooped out and white pith removed, then zest finely chopped (you’ll need 2 tsp)',
#  '350g cauliflower florets',
#  '15g parsley chopped',
#  '140g wholemeal couscous',
#  '40g toasted flaked almonds']

# %%
print(recipes[2].instructions())
# Out:
# Heat the oil in a large lidded pan over a medium heat and fry the onions for 10 mins, stirring often until golden. Stir in the peppers and cook for 5 mins more.
# Add the chilli powder, coriander and cumin, stir briefly, then tip in the passata and chickpeas along with the liquid from the cans.
# Stir in the bouillon powder, raisins and lemon zest, then add the cauliflower. Cover tightly and simmer over a medium heat for 15-20 mins until the cauliflower is tender. Stir in half the parsley.
# Meanwhile, put the couscous in a heatproof bowl and pour over 175ml boiling water from the kettle. Stir in the lemon juice, then cover and let stand for about 10 mins until the couscous has absorbed the liquid and is tender. Stir in the toasted flaked almonds and most of the remaining parsley.
# Divide half the couscous between two plates and top with half the chickpea stew and the rest of the parsley. Leave the remainder to cool for another day. Will keep covered and chilled for up to three days. Reheat the stew in a pan over a low heat with a splash of water until piping hot. Reheat the couscous in the microwave.

# %% [markdown]
# We can typically break down the cooking process into two main stages:
#
# ### 1. Ingredient Preparation
#
# This includes chopping, slicing, dicing, etc.
#
# This step is often omitted from the instructions section and is assumed to have been completed by the user already. This is evident from the above example recipe where as a prerequisite, the user has already chopped onions, deseeded and cut green peppers, lemon juiced, etc.
#
# These steps are still part of the messy cooking process, and will require a step by step guide from the agent, since we assume the user will have messy hands and will not be able to look at the recipe.
#
# ### 2. Instructions
#
# This is the actual cooking process after the ingredients have been prepared.
#
# This is a simpler task since all the steps are pre-defined in the recipe. So the agent only needs to tell the user what to do next, and handle any questions the user may have.

# %% [markdown]
# ## Session Composition
#
# Given the above, we now have a two-stage process for our session.
#
# Ingredients Prep Stage:
#
# ```
# URL --> Ingredients list --> Ingredients Preparation Step by Step Guide --> (wait for user to finish)
# ```
#
# Cooking Stage:
#
# ```
# Cooking Step by Step Guide --> (wait for user to finish)
# ```

# %% [markdown]
# ## Session Testing Implementation

# %% [markdown]
# Below, we construct an initial prompt template for the agent.
#
# It is a single prompt. I anticipate that the agent will have to be given two different graph/chains and hence two different prompts to be able to handle both stages without being confused.
#
# But, we experiment with a single system prompt to see if it is possible to handle both stages in a single prompt.

# %%
from abc import ABC, abstractmethod
from string import Template

from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
from langchain.messages import HumanMessage, SystemMessage
from loguru import logger
from recipe_scrapers import AbstractScraper


class CookingSystemPrompt(ABC):
    def __init__(self, recipe:AbstractScraper):
        self.recipe = recipe

    @abstractmethod
    def get_template(self) -> Template:
        ...

    def construct_message(self) -> SystemMessage:
        return SystemMessage(
            content=self.get_template().substitute(
                dict(
                    ingredients=self.recipe.ingredients(),
                    instructions=self.recipe.instructions()
                )
            )
        )

# %%
class SystemPrompt1(CookingSystemPrompt):
    def get_template(self) -> Template:
        return Template(
            "\n".join([
                "PURPOSE:",
                "You are a sous-chef who will be assisting with cooking for a user in the kitchen.",
                "Your tasks can be the following:",
                "- Provide alternative ingredients when an ingredient is missing.",
                "- Set timers for particular steps in a recipe where a set time is required, e.g. marinading, oven, microwave.",
                "INSTRUCTIONS:",
                "Given a list of ingredients and instructions for a recipe, you will provide a step by step guide",
                "to prompt the user on what to do next.",
                "Wait for the user to provide confirmation they've completed the step before moving to the next step.",
                "Once all steps have been completed, you will output 'STOP' so that we know the user has completed the recipe.",
                "METHOD:",
                "Break down the recipe into the following stages:",
                "1. Preparation of ingredients. This includes chopping, slicing, dicing, etc.",
                "2. Instructions for cooking the recipe.",
                "INGREDIENTS:",
                "${ingredients}",
                "INSTRUCTIONS FOR COOKING THE RECIPE:",
                "${instructions}",
            ])
        )

# %% [markdown]
# We create a mockup of what a Session object might look like for handling a recipe cooking session.
#
# A session would start with a chat model and a recipe url.
#
# The agent would be tasked with providing step-by-step guidance for cooking the recipe.
#
# The session ends when the recipe is complete, or when the user tells the agent to stop cooking.

# %%
import sqlite3
from typing import Generator, Iterable
from uuid import uuid4

from langgraph.checkpoint.sqlite import SqliteSaver
from langgraph.graph.state import CompiledStateGraph


class BaseSession:
    def __init__(
        self,
        model_config:dict,
        checkpointer_path:str | None = None,
    ):
        self.model_config = model_config
        self.checkpointer_path = checkpointer_path

        self.chat_model = init_chat_model(**self.model_config)
        self.agent = None
        self.session_id = uuid4()

    def get_runnable_config(self):
        return {"configurable": {"thread_id": self.session_id}}

    def get_checkpointer(self):
        """Get a sqlite checkpointer for the agent."""
        if self.checkpointer_path:
            return SqliteSaver(sqlite3.connect(self.checkpointer_path, check_same_thread=False))
        return None

    def get_system_prompt(self) -> str:
        pass

    def get_tools(self):
        return None

    def get_agent(self) -> CompiledStateGraph:
        """Return a CompiledStateGraph for the session."""
        logger.info("Creating agent...")
        return create_agent(
            self.chat_model,
            tools=self.get_tools(),
            system_prompt=self.get_system_prompt(),
            checkpointer=self.get_checkpointer()
        )

    @abstractmethod
    def get_user_input(self) -> str:
        pass

    @abstractmethod
    def step(self, input:str):
        """Take the next step in the user-agent interaction.

        Given a user input, run the agent and return a response.
        """
        pass

    @abstractmethod
    def emit(self):
        """Emit output from the agent to the user."""
        pass

    @abstractmethod
    def session_ended(self) -> bool:
        """Check if the session has ended."""
        pass

    def get_message_history(self):
        return self.agent.get_state(self.get_runnable_config()).values['messages']

    def run(self):
        """Run the session."""
        logger.info("running session...")
        self.agent = self.get_agent()
        while not self.session_ended():
            qry = self.get_user_input()
            agent_response = self.step(qry)
            self.emit(agent_response)


class Session(BaseSession):
    def __init__(
        self,
        model_config:dict,
        recipe_url:str,
        system_prompt_ctr: CookingSystemPrompt,
        checkpointer_path:str | None = None,
    ):
        super().__init__(model_config, checkpointer_path)
        self.system_prompt_ctr = system_prompt_ctr
        self.recipe_url = recipe_url
        self._stop_session_flag = False
        self._stop_session_token = "STOP"

    def get_system_prompt(self) -> str:
        """Get the system prompt for the agent given a recipe url."""
        recipe = scrape_me(self.recipe_url)
        return self.system_prompt_ctr(recipe).construct_message().content

    def step(self, user_input:str):
        """Take the next step in the user-agent interaction.

        Given a user input, run the agent and return a response.
        """
        if self._stop_session_flag:
            return {"messages": [{"content": "Session ended."}]}

        output = self.agent.invoke(
            dict(messages=[HumanMessage(content=user_input)]),
            config = self.get_runnable_config(),
            stream_mode="values"
        )

        if output['messages'][-1].content == self._stop_session_token:
            self._stop_session_flag = True

        return output

    def emit(self, output):
        """Emit output from the agent to the user."""
        output['messages'][-1].pretty_print()

    def get_user_input(self) -> str:
        """Get the next input from the user."""
        logger.info("awaiting user input...")
        usr_input = input("User: ")
        logger.info(f"Received user input: {usr_input}")
        self._stop_session_flag = usr_input == self._stop_session_token
        return usr_input

    def session_ended(self) -> bool:
        return self._stop_session_flag

# %% [markdown]
# We run the session given some initial configuration.

# %%
from dotenv import load_dotenv

load_dotenv()

model_config = dict(
    model="llama3-groq-tool-use:8b",
    model_provider="ollama",
    reasoning=False,
    num_ctx=8192,
    temperature=0
)

test_sessions = [
    Session(model_config, test_url, SystemPrompt1, checkpointer_path=f".db{i}")
    for i, test_url in enumerate(test_urls)
]

# %%
test_sessions[0].run()
# Out:
# 2025-10-27 02:37:44.954 | INFO     | __main__:run:74 - running session...
# 2025-10-27 02:37:44.955 | INFO     | __main__:get_agent:39 - Creating agent...
# 2025-10-27 02:37:46.854 | INFO     | __main__:get_user_input:127 - awaiting user input...
# ================================== Ai Message ==================================
#
# Let's start with preparing the ingredients. Do you have all the ingredients ready?
# 2025-10-27 02:37:52.082 | INFO     | __main__:get_user_input:127 - awaiting user input...
# ================================== Ai Message ==================================
#
# Great! Let's begin by mixing together the turkey, spinach, feta, eggs, and garlic in a large bowl until well combined. Then, form into 8 patties.
# 2025-10-27 02:37:59.593 | INFO     | __main__:get_user_input:127 - awaiting user input...
# ================================== Ai Message ==================================
#
# Now, preheat an outdoor grill for medium-high heat and lightly oil the grate.

# %% [markdown]
# We now create a test bed on which we can run multiple sessions with different configurations.

# %% [markdown]
# ## Trial Configurations

# %%
trial_model_configs = [
    dict(
        model="llama3-groq-tool-use:8b",
        model_provider="ollama",
        reasoning=False,
        num_ctx=8192,
        temperature=0.1
    ),
    dict(
        model="llama3.2:latest",
        model_provider="ollama",
        reasoning=False,
        num_ctx=8192,
        temperature=0.1
    ),
    dict(
        model="qwen3:latest",
        model_provider="ollama",
        reasoning=True,
        num_ctx=8192,
        temperature=0.1
    ),
]

test_urls = [
    "https://www.allrecipes.com/recipe/158968/spinach-and-feta-turkey-burgers/",
    "https://www.allrecipes.com/recipe/93037/fresh-cranberry-salsa/",
    "https://www.bbcgoodfood.com/recipes/spicy-chickpea-stew",
    "https://www.bbcgoodfood.com/recipes/oven-baked-risotto",
    "https://www.bbcgoodfood.com/recipes/veggie-shepherds-pie-sweet-potato-mash",
    "https://www.allrecipes.com/recipe/157940/outrageous-warm-chicken-nacho-dip/",
    "https://dinnerthendessert.com/pork-dim-sum-recipe/",
    "https://www.hellofresh.com/recipes/fuego-chicken-fajita-tacos-68c7e2b837c1ef9942a55306"
]

# %%
import itertools
from pathlib import Path
from tqdm import tqdm


def mock_get_user_input():
    return 'yes'


trial_configs = itertools.product(trial_model_configs, test_urls)
logger.info(f"Executing {len(trial_model_configs) * len(test_urls)} trial sessions...")

completed_sessions = []
i = 0
for model_config, test_url in tqdm(trial_configs):
    # set up experiment checkpoint db
    checkpointer_dir = Path(f"./experiment{i}/")
    checkpointer_dir.mkdir(parents=True, exist_ok=True)
    checkpointer_path = checkpointer_dir / ".db"

    # run session
    session = Session(model_config, test_url, SystemPrompt1, checkpointer_path=checkpointer_path)
    session.get_user_input = mock_get_user_input
    session.run()

    completed_sessions.append(session)

    i += 1
# Out:
# 2025-10-28 16:21:09.392 | INFO     | __main__:<module>:11 - Executing 24 trial sessions...
# 0it [00:00, ?it/s]2025-10-28 16:21:09.473 | INFO     | __main__:run:74 - running session...
# 2025-10-28 16:21:09.474 | INFO     | __main__:get_agent:39 - Creating agent...
# ================================== Ai Message ==================================
#
# Great! Let's start with preparing the ingredients. Do you have all the ingredients ready?
# ================================== Ai Message ==================================
#
# Perfect! Now, let's move on to cooking the recipe. Preheat an outdoor grill for medium-high heat and lightly oil the grate.
# ================================== Ai Message ==================================
#
# Next, mix together turkey, spinach, feta, eggs, and garlic in a large bowl until well combined; form into 8 patties.
# ================================== Ai Message ==================================
#
# Finally, cook patties on the preheated grill on both sides until no longer pink in the center, 15 to 20 minutes. An instant-read thermometer inserted into the center of patties should read at least 165 degrees F (74 degrees C).
# 1it [00:13, 13.78s/it]2025-10-28 16:21:23.237 | INFO     | __main__:run:74 - running session...
# 2025-10-28 16:21:23.238 | INFO     | __main__:get_agent:39 - Creating agent...
# ================================== Ai Message ==================================
#
# STOP
# ================================== Ai Message ==================================
#
# Great! Let's start with preparing the ingredients. Could you please chop the cranberries into smaller pieces?
# ================================== Ai Message ==================================
#
# Next, could you dice the cucumber and chop the celery?
# ================================== Ai Message ==================================
#
# Now, finely chop the pickled jalapeño peppers.
# ================================== Ai Message ==================================
#
# Let's move on to cooking the recipe. Place the chopped cranberries into a food processor and pulse until they're still slightly chunky.
# ================================== Ai Message ==================================
#
# Transfer the processed cranberries to a serving bowl. Stir in the sugar, orange liqueur, cucumber, celery, and jalapeño. Let it sit at room temperature for 15 minutes before serving.
# 2it [00:22, 10.86s/it]2025-10-28 16:21:32.034 | INFO     | __main__:run:74 - running session...
# 2025-10-28 16:21:32.035 | INFO     | __main__:get_agent:39 - Creating agent...
# ================================== Ai Message ==================================
#
# STOP
# ================================== Ai Message ==================================
#
# Great! Let's start by preparing the ingredients. Do you have all the ingredients listed?
# ================================== Ai Message ==================================
#
# Perfect! First, let's chop the onions. How many onions do we need to chop?
# ================================== Ai Message ==================================
#
# Got it. Now, can you deseed and cut the green peppers into cubes?
# ================================== Ai Message ==================================
#
# Excellent. Next, I'll need you to grind the coriander and cumin. Do you have a spice grinder or should we use pre-ground spices?
# ================================== Ai Message ==================================
#
# Perfect. Now that we have all our ingredients ready, let's start cooking! Heat the rapeseed oil in a large lidded pan over medium heat.
# ================================== Ai Message ==================================
#
# Great! Fry the onions for 10 minutes, stirring often until they're golden. Then, add the peppers and cook for another 5 minutes.
# ================================== Ai Message ==================================
#
# Now, add the chilli powder, coriander, and cumin. Stir briefly, then tip in the passata and chickpeas along with their liquid.
# ================================== Ai Message ==================================
#
# Stir in the bouillon powder, raisins, and lemon zest. Then, add the cauliflower. Cover tightly and simmer over medium heat for 15-20 minutes until the cauliflower is tender.
# ================================== Ai Message ==================================
#
# While the stew is cooking, prepare the couscous. Put it in a heatproof bowl and pour over 175ml boiling water from the kettle. Stir in the lemon juice, then cover and let stand for about 10 minutes until the couscous has absorbed the liquid and is tender.
# ================================== Ai Message ==================================
#
# Finally, stir in the toasted flaked almonds and most of the remaining parsley. Divide half the couscous between two plates and top with half the chickpea stew and the rest of the parsley. Leave the remainder to cool for another day.
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your delicious meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Let's start a new recipe. What would you like to cook next?
# ================================== Ai Message ==================================
#
# Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.
# ================================== Ai Message ==================================
#
# I'm ready when you are!
# ================================== Ai Message ==================================
#
# Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?
# ================================== Ai Message ==================================
#
# Great! Now that we have all our ingredients ready, let's start cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the new recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# That's it for now. If you need any more assistance or have other questions, feel free to ask.
# ================================== Ai Message ==================================
#
# Perfect! Have a great day and happy cooking!
# ================================== Ai Message ==================================
#
# STOP! You've completed the recipe. Enjoy your meal!
# ================================== Ai Message ==================================
#
# Great! If you have any other recipes or need assistance with anything else, feel free to ask.
# 2it [22:40, 680.40s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 24
#      22 session = Session(model_config, test_url, SystemPrompt1, checkpointer_path=checkpointer_path)
#      23 session.get_user_input = mock_get_user_input
# ---> 24 session.run()
#      26 completed_sessions.append(session)
#      28 i += 1
#
# Cell In[37], line 78, in BaseSession.run(self)
#      76 while not self.session_ended():
#      77     qry = self.get_user_input()
# ---> 78     agent_response = self.step(qry)
#      79     self.emit(agent_response)
#
# Cell In[37], line 109, in Session.step(self, user_input)
#     106 if self._stop_session_flag:
#     107     return {"messages": [{"content": "Session ended."}]}
# --> 109 output = self.agent.invoke(
#     110     dict(messages=[HumanMessage(content=user_input)]),
#     111     config = self.get_runnable_config(),
#     112     stream_mode="values"
#     113 )
#     115 if output['messages'][-1].content == self._stop_session_token:
#     116     self._stop_session_flag = True
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/langgraph/pregel/main.py:3094, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3091 chunks: list[dict[str, Any] | Any] = []
#    3092 interrupts: list[Interrupt] = []
# -> 3094 for chunk in self.stream(
#    3095     input,
# ...
#    2685     # emit output
#    2686     yield from _output(
#    2687         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2688     )
#    2689 loop.after_tick()
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/langgraph/pregel/_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/langgraph/pregel/_retry.py:42, in run_with_retry(task, retry_policy, configurable)
#      40     task.writes.clear()
#      41     # run the task
# ---> 42     return task.proc.invoke(task.input, config)
#      43 except ParentCommand as exc:
#      44     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/langchain/agents/factory.py:1034, in create_agent.<locals>.model_node(state, runtime)
#    1021 request = ModelRequest(
#    1022     model=model,
#    1023     tools=default_tools,
#    (...)
#    1029     runtime=runtime,
#    1030 )
#    1032 if wrap_model_call_handler is None:
#    1033     # No handlers - execute directly
# -> 1034     response = _execute_model_sync(request)
#    1035 else:
#    1036     # Call composed handler with base handler
#    1037     response = wrap_model_call_handler(request, _execute_model_sync)
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/langchain/agents/factory.py:1007, in create_agent.<locals>._execute_model_sync(request)
#    1004 if request.system_prompt:
#    1005     messages = [SystemMessage(request.system_prompt), *messages]
# -> 1007 output = model_.invoke(messages)
#    1009 # Handle model output to get messages and structured_response
#    1010 handled_output = _handle_model_output(output, effective_response_format)
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/langchain_core/runnables/base.py:5492, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5485 @override
#    5486 def invoke(
#    5487     self,
#    (...)
#    5490     **kwargs: Any | None,
#    5491 ) -> Output:
# -> 5492     return self.bound.invoke(
#    5493         input,
#    5494         self._merge_configs(config),
#    5495         **{**self.kwargs, **kwargs},
#    5496     )
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:379, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     365 @override
#     366 def invoke(
#     367     self,
#    (...)
#     372     **kwargs: Any,
#     373 ) -> AIMessage:
#     374     config = ensure_config(config)
#     375     return cast(
#     376         "AIMessage",
#     377         cast(
#     378             "ChatGeneration",
# --> 379             self.generate_prompt(
#     380                 [self._convert_input(input)],
#     381                 stop=stop,
#     382                 callbacks=config.get("callbacks"),
#     383                 tags=config.get("tags"),
#     384                 metadata=config.get("metadata"),
#     385                 run_name=config.get("run_name"),
#     386                 run_id=config.pop("run_id", None),
#     387                 **kwargs,
#     388             ).generations[0][0],
#     389         ).message,
#     390     )
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1088, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1079 @override
#    1080 def generate_prompt(
#    1081     self,
#    (...)
#    1085     **kwargs: Any,
#    1086 ) -> LLMResult:
#    1087     prompt_messages = [p.to_messages() for p in prompts]
# -> 1088     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:903, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     900 for i, m in enumerate(input_messages):
#     901     try:
#     902         results.append(
# --> 903             self._generate_with_cache(
#     904                 m,
#     905                 stop=stop,
#     906                 run_manager=run_managers[i] if run_managers else None,
#     907                 **kwargs,
#     908             )
#     909         )
#     910     except BaseException as e:
#     911         if run_managers:
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1192, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1190     result = generate_from_stream(iter(chunks))
#    1191 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1192     result = self._generate(
#    1193         messages, stop=stop, run_manager=run_manager, **kwargs
#    1194     )
#    1195 else:
#    1196     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/langchain_ollama/chat_models.py:1025, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#    1018 def _generate(
#    1019     self,
#    1020     messages: list[BaseMessage],
#    (...)
#    1023     **kwargs: Any,
#    1024 ) -> ChatResult:
# -> 1025     final_chunk = self._chat_stream_with_aggregation(
#    1026         messages, stop, run_manager, verbose=self.verbose, **kwargs
#    1027     )
#    1028     generation_info = final_chunk.generation_info
#    1029     chat_generation = ChatGeneration(
#    1030         message=AIMessage(
#    1031             content=final_chunk.text,
#    (...)
#    1038         generation_info=generation_info,
#    1039     )
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/langchain_ollama/chat_models.py:960, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     951 def _chat_stream_with_aggregation(
#     952     self,
#     953     messages: list[BaseMessage],
#    (...)
#     957     **kwargs: Any,
#     958 ) -> ChatGenerationChunk:
#     959     final_chunk = None
# --> 960     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#     961         if final_chunk is None:
#     962             final_chunk = chunk
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/langchain_ollama/chat_models.py:1049, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#    1042 def _iterate_over_stream(
#    1043     self,
#    1044     messages: list[BaseMessage],
#    1045     stop: list[str] | None = None,
#    1046     **kwargs: Any,
#    1047 ) -> Iterator[ChatGenerationChunk]:
#    1048     reasoning = kwargs.get("reasoning", self.reasoning)
# -> 1049     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#    1050         if not isinstance(stream_resp, str):
#    1051             content = (
#    1052                 stream_resp["message"]["content"]
#    1053                 if "message" in stream_resp and "content" in stream_resp["message"]
#    1054                 else ""
#    1055             )
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/langchain_ollama/chat_models.py:947, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     945 if chat_params["stream"]:
#     946     if self._client:
# --> 947         yield from self._client.chat(**chat_params)
#     948 elif self._client:
#     949     yield self._client.chat(**chat_params)
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/ollama/_client.py:174, in Client._request.<locals>.inner()
#     173 def inner():
# --> 174   with self._client.stream(*args, **kwargs) as r:
#     175     try:
#     176       r.raise_for_status()
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/httpx/_client.py:868, in Client.stream(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     845 """
#     846 Alternative to `httpx.request()` that streams the response body
#     847 instead of loading it into memory at once.
#    (...)
#     853 [0]: /quickstart#streaming-responses
#     854 """
#     855 request = self.build_request(
#     856     method=method,
#     857     url=url,
#    (...)
#     866     extensions=extensions,
#     867 )
# --> 868 response = self.send(
#     869     request=request,
#     870     auth=auth,
#     871     follow_redirects=follow_redirects,
#     872     stream=True,
#     873 )
#     874 try:
#     875     yield response
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/miniconda3/envs/sous-chef/lib/python3.12/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %% [markdown]
# From the below testing, it's evident that there is a major issue in our session + agent interaction where we can't reliably terminate the session after the recipe is complete.
#
# We end the notebook here for now, and we'll address this issue in the next notebook.

# %%
session.get_message_history()
# Out:
# [HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='9cb1979c-2aa6-4ccd-8622-8c6efac4cbfe'),
#  AIMessage(content="Great! Let's start by preparing the ingredients. Do you have all the ingredients listed?", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:21:35.78952Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3463705000, 'load_duration': 66766458, 'prompt_eval_count': 615, 'prompt_eval_duration': 2374054625, 'eval_count': 19, 'eval_duration': 1020586958, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--c6fc6935-9b42-4419-80ef-aeab26b1bad9-0', usage_metadata={'input_tokens': 615, 'output_tokens': 19, 'total_tokens': 634}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='58a38b19-93bf-44ec-b12b-8f0ec32e01c1'),
#  AIMessage(content="Perfect! First, let's chop the onions. How many onions do we need to chop?", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:21:37.077561Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1275270917, 'load_duration': 45324042, 'prompt_eval_count': 644, 'prompt_eval_duration': 196095125, 'eval_count': 20, 'eval_duration': 1032191834, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--b564ebf2-a1d8-417f-969e-3d41c5450973-0', usage_metadata={'input_tokens': 644, 'output_tokens': 20, 'total_tokens': 664}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='1c5581d1-ea3c-48da-b6d0-153fa5d6326c'),
#  AIMessage(content='Got it. Now, can you deseed and cut the green peppers into cubes?', additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:21:38.250576Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1161947500, 'load_duration': 42934125, 'prompt_eval_count': 674, 'prompt_eval_duration': 191063375, 'eval_count': 18, 'eval_duration': 925853500, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--d7eb0931-d949-4a6d-808d-4e41fb0fe680-0', usage_metadata={'input_tokens': 674, 'output_tokens': 18, 'total_tokens': 692}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='073c7b0c-a1a5-44b1-83ba-693399f32604'),
#  AIMessage(content="Excellent. Next, I'll need you to grind the coriander and cumin. Do you have a spice grinder or should we use pre-ground spices?", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:21:40.296689Z', 'done': True, 'done_reason': 'stop', 'total_duration': 2032250250, 'load_duration': 45154000, 'prompt_eval_count': 702, 'prompt_eval_duration': 192275209, 'eval_count': 33, 'eval_duration': 1792091625, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--f4014b7d-444d-4a19-97ae-69494fa47aee-0', usage_metadata={'input_tokens': 702, 'output_tokens': 33, 'total_tokens': 735}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='22446c54-598d-4f65-90ce-6178ad6dc689'),
#  AIMessage(content="Perfect. Now that we have all our ingredients ready, let's start cooking! Heat the rapeseed oil in a large lidded pan over medium heat.", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:21:42.399553Z', 'done': True, 'done_reason': 'stop', 'total_duration': 2098256958, 'load_duration': 41006292, 'prompt_eval_count': 745, 'prompt_eval_duration': 192676958, 'eval_count': 34, 'eval_duration': 1861599708, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--fb9b9f03-fcd0-4714-82b7-045c13b25b5f-0', usage_metadata={'input_tokens': 745, 'output_tokens': 34, 'total_tokens': 779}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='5c13b9b1-5e6c-4fe3-8782-13052ceaca44'),
#  AIMessage(content="Great! Fry the onions for 10 minutes, stirring often until they're golden. Then, add the peppers and cook for another 5 minutes.", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:21:44.386938Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1974941083, 'load_duration': 44898708, 'prompt_eval_count': 789, 'prompt_eval_duration': 195652167, 'eval_count': 31, 'eval_duration': 1730436333, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--cf6cb7ca-dcb3-4e2a-b86f-00a987f4c39c-0', usage_metadata={'input_tokens': 789, 'output_tokens': 31, 'total_tokens': 820}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='4072d244-789b-45ca-8f3b-be2db89c474c'),
#  AIMessage(content='Now, add the chilli powder, coriander, and cumin. Stir briefly, then tip in the passata and chickpeas along with their liquid.', additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:21:46.524728Z', 'done': True, 'done_reason': 'stop', 'total_duration': 2123779459, 'load_duration': 43397417, 'prompt_eval_count': 830, 'prompt_eval_duration': 192616250, 'eval_count': 35, 'eval_duration': 1883047375, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--f8c07b5a-1988-41c8-b69f-7a1afd16f542-0', usage_metadata={'input_tokens': 830, 'output_tokens': 35, 'total_tokens': 865}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='ca18f3c7-549c-4e7b-968c-4082a9796b60'),
#  AIMessage(content='Stir in the bouillon powder, raisins, and lemon zest. Then, add the cauliflower. Cover tightly and simmer over medium heat for 15-20 minutes until the cauliflower is tender.', additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:21:49.093457Z', 'done': True, 'done_reason': 'stop', 'total_duration': 2555303500, 'load_duration': 45754125, 'prompt_eval_count': 875, 'prompt_eval_duration': 200605459, 'eval_count': 41, 'eval_duration': 2302475958, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--cfc3edad-226c-4cdb-8bd4-4e1428560af9-0', usage_metadata={'input_tokens': 875, 'output_tokens': 41, 'total_tokens': 916}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='314b40ac-9d4d-408e-b7a3-3b139bb34c05'),
#  AIMessage(content='While the stew is cooking, prepare the couscous. Put it in a heatproof bowl and pour over 175ml boiling water from the kettle. Stir in the lemon juice, then cover and let stand for about 10 minutes until the couscous has absorbed the liquid and is tender.', additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:21:52.680559Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3572549750, 'load_duration': 46125334, 'prompt_eval_count': 926, 'prompt_eval_duration': 193410916, 'eval_count': 61, 'eval_duration': 3326594375, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--ef1ccbcd-1419-4ff2-89ac-285250528144-0', usage_metadata={'input_tokens': 926, 'output_tokens': 61, 'total_tokens': 987}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='a5d5cefd-4938-4a3b-b13e-08fdf6216c57'),
#  AIMessage(content='Finally, stir in the toasted flaked almonds and most of the remaining parsley. Divide half the couscous between two plates and top with half the chickpea stew and the rest of the parsley. Leave the remainder to cool for another day.', additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:21:55.72802Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3034657041, 'load_duration': 43429125, 'prompt_eval_count': 997, 'prompt_eval_duration': 194200334, 'eval_count': 51, 'eval_duration': 2789098458, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--839f5395-c90f-4536-8e59-8824b166be6e-0', usage_metadata={'input_tokens': 997, 'output_tokens': 51, 'total_tokens': 1048}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='58594644-15ff-433e-8998-03174efdc094'),
#  AIMessage(content="STOP! You've completed the recipe. Enjoy your delicious meal!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:21:56.720426Z', 'done': True, 'done_reason': 'stop', 'total_duration': 978027458, 'load_duration': 43922458, 'prompt_eval_count': 1058, 'prompt_eval_duration': 194703000, 'eval_count': 14, 'eval_duration': 731069958, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--315ebf44-1612-4ba6-95a5-c49fc2a76986-0', usage_metadata={'input_tokens': 1058, 'output_tokens': 14, 'total_tokens': 1072}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='1cd9e518-c750-4eeb-bf43-163df4aa9d42'),
#  AIMessage(content='Great! If you have any other recipes or need assistance with anything else, feel free to ask.', additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:21:58.11192Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1375682125, 'load_duration': 48085791, 'prompt_eval_count': 1082, 'prompt_eval_duration': 195382333, 'eval_count': 21, 'eval_duration': 1122256792, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--7cb3d4e6-2fa3-43bf-81dd-f274e61da2ad-0', usage_metadata={'input_tokens': 1082, 'output_tokens': 21, 'total_tokens': 1103}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='67d2f208-b984-469e-909c-3d76a3cfdcfe'),
#  AIMessage(content="Perfect! Let's start a new recipe. What would you like to cook next?", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:21:59.333303Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1207467000, 'load_duration': 46500708, 'prompt_eval_count': 1113, 'prompt_eval_duration': 194092084, 'eval_count': 18, 'eval_duration': 956813791, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--ade9f7a1-a7f0-473a-9743-046d73db05e8-0', usage_metadata={'input_tokens': 1113, 'output_tokens': 18, 'total_tokens': 1131}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='0f4396ae-fe3e-4f09-b584-9b6429aeca17'),
#  AIMessage(content="Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:00.912055Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1560504250, 'load_duration': 49152417, 'prompt_eval_count': 1141, 'prompt_eval_duration': 194693167, 'eval_count': 24, 'eval_duration': 1302573875, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--753eebb9-65f3-4902-aeb3-3784e7cb4bb4-0', usage_metadata={'input_tokens': 1141, 'output_tokens': 24, 'total_tokens': 1165}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='aef49709-98b1-4a96-9649-87cf6cb6ad77'),
#  AIMessage(content="I'm ready when you are!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:01.578233Z', 'done': True, 'done_reason': 'stop', 'total_duration': 651154000, 'load_duration': 48087666, 'prompt_eval_count': 1175, 'prompt_eval_duration': 195130083, 'eval_count': 8, 'eval_duration': 394769167, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--a0354206-8909-48ab-b0bd-11f80b0642d2-0', usage_metadata={'input_tokens': 1175, 'output_tokens': 8, 'total_tokens': 1183}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='57f0fb98-4734-421b-9306-dbf7113f8923'),
#  AIMessage(content="Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:02.980258Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1387857916, 'load_duration': 47546458, 'prompt_eval_count': 1193, 'prompt_eval_duration': 194903500, 'eval_count': 21, 'eval_duration': 1131551292, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--f4f8d1bd-fc0c-4651-85b5-d477aa3fa46b-0', usage_metadata={'input_tokens': 1193, 'output_tokens': 21, 'total_tokens': 1214}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='2e7e674e-33ad-452f-a40e-079241dcfd84'),
#  AIMessage(content="Great! Now that we have all our ingredients ready, let's start cooking!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:04.160732Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1164923000, 'load_duration': 50519500, 'prompt_eval_count': 1224, 'prompt_eval_duration': 195417917, 'eval_count': 17, 'eval_duration': 904178541, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--fbd81621-32d9-4c35-baf1-9266d7577c99-0', usage_metadata={'input_tokens': 1224, 'output_tokens': 17, 'total_tokens': 1241}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='fec10eb4-4abc-4a2b-952f-b256ce35b240'),
#  AIMessage(content="STOP! You've completed the new recipe. Enjoy your meal!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:05.182499Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1004393833, 'load_duration': 51738666, 'prompt_eval_count': 1251, 'prompt_eval_duration': 195203375, 'eval_count': 14, 'eval_duration': 738894416, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--54e6c2b0-a1b1-4f99-8dae-decafa074fa1-0', usage_metadata={'input_tokens': 1251, 'output_tokens': 14, 'total_tokens': 1265}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='89e91ea9-e4c8-48ef-ba27-0f9a71b290ff'),
#  AIMessage(content="That's it for now. If you need any more assistance or have other questions, feel free to ask.", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:06.71133Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1513380708, 'load_duration': 48510166, 'prompt_eval_count': 1275, 'prompt_eval_duration': 195552916, 'eval_count': 23, 'eval_duration': 1251596250, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--40a62d81-ffdf-4144-8db5-ded2f737c8b8-0', usage_metadata={'input_tokens': 1275, 'output_tokens': 23, 'total_tokens': 1298}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='ee88eb23-e0d2-4f15-b0b5-a2a9cab1fb1a'),
#  AIMessage(content='Perfect! Have a great day and happy cooking!', additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:07.582994Z', 'done': True, 'done_reason': 'stop', 'total_duration': 854867583, 'load_duration': 47435125, 'prompt_eval_count': 1308, 'prompt_eval_duration': 195971292, 'eval_count': 11, 'eval_duration': 592872583, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--80a03b72-7abb-4a7f-b6f7-10a21cb239dc-0', usage_metadata={'input_tokens': 1308, 'output_tokens': 11, 'total_tokens': 1319}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='9aae7d90-3fa9-4391-accc-af46c38c5d35'),
#  AIMessage(content="STOP! You've completed the recipe. Enjoy your meal!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:08.555763Z', 'done': True, 'done_reason': 'stop', 'total_duration': 955143625, 'load_duration': 48662125, 'prompt_eval_count': 1329, 'prompt_eval_duration': 196016292, 'eval_count': 13, 'eval_duration': 687552708, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--8afd3333-b3f9-44c1-8aed-de5eeeabe0ee-0', usage_metadata={'input_tokens': 1329, 'output_tokens': 13, 'total_tokens': 1342}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='e4c28e9e-b359-4c03-a704-f7cd790f85bf'),
#  AIMessage(content='Great! If you have any other recipes or need assistance with anything else, feel free to ask.', additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:09.977508Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1410747083, 'load_duration': 42184542, 'prompt_eval_count': 1352, 'prompt_eval_duration': 196520875, 'eval_count': 21, 'eval_duration': 1152569458, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--0ead9fd5-5e49-41f5-a7ef-792130ea5e54-0', usage_metadata={'input_tokens': 1352, 'output_tokens': 21, 'total_tokens': 1373}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='bdec05df-5244-450e-85ab-5e49e05fb1bc'),
#  AIMessage(content="Perfect! Let's start a new recipe. What would you like to cook next?", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:11.240384Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1245886375, 'load_duration': 49296041, 'prompt_eval_count': 1383, 'prompt_eval_duration': 196527333, 'eval_count': 18, 'eval_duration': 977791792, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--f38e56fd-4de7-4644-bb3d-0820eb8597f5-0', usage_metadata={'input_tokens': 1383, 'output_tokens': 18, 'total_tokens': 1401}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='65462b51-f3af-4f23-8ed8-300d5872775b'),
#  AIMessage(content="Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:12.861682Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1604447667, 'load_duration': 48592833, 'prompt_eval_count': 1411, 'prompt_eval_duration': 197275708, 'eval_count': 24, 'eval_duration': 1334227625, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--dfacb94f-9848-4eb7-bf85-220c0c123be9-0', usage_metadata={'input_tokens': 1411, 'output_tokens': 24, 'total_tokens': 1435}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='39f99efb-1bb5-443a-b800-1c22732fe1d9'),
#  AIMessage(content="I'm ready when you are!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:13.557458Z', 'done': True, 'done_reason': 'stop', 'total_duration': 678762041, 'load_duration': 48216458, 'prompt_eval_count': 1445, 'prompt_eval_duration': 197242875, 'eval_count': 8, 'eval_duration': 408050459, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--ee43dc44-6d06-41b5-874c-d1036751f905-0', usage_metadata={'input_tokens': 1445, 'output_tokens': 8, 'total_tokens': 1453}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='1a85b72f-70ed-49fc-b8d6-1881e34106a8'),
#  AIMessage(content="Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:14.991693Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1425109792, 'load_duration': 41164667, 'prompt_eval_count': 1463, 'prompt_eval_duration': 197283375, 'eval_count': 21, 'eval_duration': 1160496375, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--faa27a8f-3c14-4e7e-87e0-faaf11e5dcbf-0', usage_metadata={'input_tokens': 1463, 'output_tokens': 21, 'total_tokens': 1484}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='0b8a8251-22fa-463e-9b8c-669d80ac628d'),
#  AIMessage(content="Great! Now that we have all our ingredients ready, let's start cooking!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:16.216947Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1208782458, 'load_duration': 48828125, 'prompt_eval_count': 1494, 'prompt_eval_duration': 197628000, 'eval_count': 17, 'eval_duration': 932966333, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--11d4dd8a-a4cf-460a-b80e-344d593d2cd6-0', usage_metadata={'input_tokens': 1494, 'output_tokens': 17, 'total_tokens': 1511}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='72fb6d41-fd7a-424b-b63d-81fda28df0fc'),
#  AIMessage(content="STOP! You've completed the new recipe. Enjoy your meal!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:17.278073Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1039665792, 'load_duration': 51816250, 'prompt_eval_count': 1521, 'prompt_eval_duration': 197489167, 'eval_count': 14, 'eval_duration': 756879083, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--4997b89a-5b10-4957-847e-8082a40c6751-0', usage_metadata={'input_tokens': 1521, 'output_tokens': 14, 'total_tokens': 1535}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='e78e2ffa-7ea7-44b3-984d-486848685628'),
#  AIMessage(content="That's it for now. If you need any more assistance or have other questions, feel free to ask.", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:18.86474Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1568083125, 'load_duration': 51317334, 'prompt_eval_count': 1545, 'prompt_eval_duration': 198752000, 'eval_count': 23, 'eval_duration': 1283826125, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--562c2e09-d10d-4ad1-9006-350a242da3ac-0', usage_metadata={'input_tokens': 1545, 'output_tokens': 23, 'total_tokens': 1568}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='a8196d7c-e8d4-4ddc-98d0-a8cbd094daea'),
#  AIMessage(content='Perfect! Have a great day and happy cooking!', additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:19.75264Z', 'done': True, 'done_reason': 'stop', 'total_duration': 869548166, 'load_duration': 49158833, 'prompt_eval_count': 1578, 'prompt_eval_duration': 198832333, 'eval_count': 11, 'eval_duration': 584230250, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--c259908d-d6ec-4c9b-9038-c3bd4672f765-0', usage_metadata={'input_tokens': 1578, 'output_tokens': 11, 'total_tokens': 1589}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='022296ff-c8f2-4177-843d-ecce71c8f5c0'),
#  AIMessage(content="STOP! You've completed the recipe. Enjoy your meal!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:20.833285Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1062074666, 'load_duration': 52833125, 'prompt_eval_count': 1599, 'prompt_eval_duration': 198101792, 'eval_count': 13, 'eval_duration': 773416958, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--f77a245e-62d2-4dab-b141-563a1b581b7e-0', usage_metadata={'input_tokens': 1599, 'output_tokens': 13, 'total_tokens': 1612}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='f95bea98-e84b-4c66-a885-6f734d2630df'),
#  AIMessage(content='Great! If you have any other recipes or need assistance with anything else, feel free to ask.', additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:22.323327Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1469854166, 'load_duration': 50769291, 'prompt_eval_count': 1622, 'prompt_eval_duration': 199023125, 'eval_count': 21, 'eval_duration': 1179735792, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--8212f862-3193-4921-aba3-d2a4145777c0-0', usage_metadata={'input_tokens': 1622, 'output_tokens': 21, 'total_tokens': 1643}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='bf163b89-634b-44be-8a65-a9c041643b67'),
#  AIMessage(content="Perfect! Let's start a new recipe. What would you like to cook next?", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:23.635216Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1291185000, 'load_duration': 50516958, 'prompt_eval_count': 1653, 'prompt_eval_duration': 199305917, 'eval_count': 18, 'eval_duration': 1002099958, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--85734b80-f861-4352-aee1-0822e0cc7a9e-0', usage_metadata={'input_tokens': 1653, 'output_tokens': 18, 'total_tokens': 1671}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='e8be8b38-d2f8-41d7-b4ac-8e7f1a553236'),
#  AIMessage(content="Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:25.311584Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1653509666, 'load_duration': 50483208, 'prompt_eval_count': 1681, 'prompt_eval_duration': 199336625, 'eval_count': 24, 'eval_duration': 1360169417, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--c7050111-ddf8-4f18-a836-d7720e057578-0', usage_metadata={'input_tokens': 1681, 'output_tokens': 24, 'total_tokens': 1705}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='6e595fd8-1cf8-4f0e-8db6-5aec1ba38214'),
#  AIMessage(content="I'm ready when you are!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:26.042742Z', 'done': True, 'done_reason': 'stop', 'total_duration': 711304875, 'load_duration': 53595125, 'prompt_eval_count': 1715, 'prompt_eval_duration': 199377750, 'eval_count': 8, 'eval_duration': 413848375, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--65dcb362-76ac-4151-91db-c4b5a6e37938-0', usage_metadata={'input_tokens': 1715, 'output_tokens': 8, 'total_tokens': 1723}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='3343bb55-dd8e-42c2-9fec-32fc26d96e36'),
#  AIMessage(content="Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:27.546929Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1484528375, 'load_duration': 50067041, 'prompt_eval_count': 1733, 'prompt_eval_duration': 199944542, 'eval_count': 21, 'eval_duration': 1187265458, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--b847fa55-b1c9-4c73-b7e0-2f64560c2968-0', usage_metadata={'input_tokens': 1733, 'output_tokens': 21, 'total_tokens': 1754}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='201dbeb2-2d6b-44b4-a57a-010cbe32555c'),
#  AIMessage(content="Great! Now that we have all our ingredients ready, let's start cooking!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:28.828533Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1262223125, 'load_duration': 51216208, 'prompt_eval_count': 1764, 'prompt_eval_duration': 200210500, 'eval_count': 17, 'eval_duration': 961977916, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--2d063542-6ecf-4c5d-bb90-1f13e33ff6df-0', usage_metadata={'input_tokens': 1764, 'output_tokens': 17, 'total_tokens': 1781}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='8bf2f159-9834-42b7-a405-5c534bf90944'),
#  AIMessage(content="STOP! You've completed the new recipe. Enjoy your meal!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:29.917432Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1077097084, 'load_duration': 45609584, 'prompt_eval_count': 1791, 'prompt_eval_duration': 200705041, 'eval_count': 14, 'eval_duration': 783764917, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--6f970a4c-b579-4c10-8c0d-86bbeba1a87d-0', usage_metadata={'input_tokens': 1791, 'output_tokens': 14, 'total_tokens': 1805}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='c7dd2b13-cd0a-4e2d-98b1-56c20491e99d'),
#  AIMessage(content="That's it for now. If you need any more assistance or have other questions, feel free to ask.", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:31.568504Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1635606250, 'load_duration': 56825458, 'prompt_eval_count': 1815, 'prompt_eval_duration': 200600125, 'eval_count': 23, 'eval_duration': 1325551375, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--263e9ad7-4f60-459b-93cc-3cad78391fa6-0', usage_metadata={'input_tokens': 1815, 'output_tokens': 23, 'total_tokens': 1838}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='1683fb7c-5459-4af5-af54-6f42461040bf'),
#  AIMessage(content='Perfect! Have a great day and happy cooking!', additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:32.519466Z', 'done': True, 'done_reason': 'stop', 'total_duration': 931882209, 'load_duration': 50280209, 'prompt_eval_count': 1848, 'prompt_eval_duration': 201020792, 'eval_count': 11, 'eval_duration': 624322292, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--3d1b5183-4f08-4915-9848-33e6e775de18-0', usage_metadata={'input_tokens': 1848, 'output_tokens': 11, 'total_tokens': 1859}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='784ae4cb-7fcb-4841-89da-d8ec3eb13443'),
#  AIMessage(content="STOP! You've completed the recipe. Enjoy your meal!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:33.55864Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1023440334, 'load_duration': 47809209, 'prompt_eval_count': 1869, 'prompt_eval_duration': 201049916, 'eval_count': 13, 'eval_duration': 720584542, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--48a4f13c-72e5-43b2-afee-62328de276de-0', usage_metadata={'input_tokens': 1869, 'output_tokens': 13, 'total_tokens': 1882}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='17a7c8e1-e5e2-4129-9c20-d649fdeff237'),
#  AIMessage(content='Great! If you have any other recipes or need assistance with anything else, feel free to ask.', additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:35.098059Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1517738125, 'load_duration': 51765792, 'prompt_eval_count': 1892, 'prompt_eval_duration': 201871500, 'eval_count': 21, 'eval_duration': 1204515000, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--7efc39c0-6a68-4a7a-bc86-30074de82ba7-0', usage_metadata={'input_tokens': 1892, 'output_tokens': 21, 'total_tokens': 1913}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='e2f2f479-08d8-4b76-b955-c8e2d38113e4'),
#  AIMessage(content="Perfect! Let's start a new recipe. What would you like to cook next?", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:36.459886Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1340178291, 'load_duration': 51453041, 'prompt_eval_count': 1923, 'prompt_eval_duration': 201841000, 'eval_count': 18, 'eval_duration': 1024982625, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--48093b65-3f59-4970-925d-191e007b8b47-0', usage_metadata={'input_tokens': 1923, 'output_tokens': 18, 'total_tokens': 1941}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='889ebb78-354b-4961-9328-c0f504dc052b'),
#  AIMessage(content="Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:38.197052Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1716594375, 'load_duration': 50832416, 'prompt_eval_count': 1951, 'prompt_eval_duration': 202100125, 'eval_count': 24, 'eval_duration': 1399251875, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--8d8a6bc9-2b73-48bf-9898-91623a6d1c98-0', usage_metadata={'input_tokens': 1951, 'output_tokens': 24, 'total_tokens': 1975}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='fa4ab642-d6a6-40e2-b9b2-2664d5cacb01'),
#  AIMessage(content="I'm ready when you are!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:38.967335Z', 'done': True, 'done_reason': 'stop', 'total_duration': 747696667, 'load_duration': 53656959, 'prompt_eval_count': 1985, 'prompt_eval_duration': 202810375, 'eval_count': 8, 'eval_duration': 424083750, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--184ed374-7b1b-4599-98ad-6e6384711901-0', usage_metadata={'input_tokens': 1985, 'output_tokens': 8, 'total_tokens': 1993}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='e6c65961-4095-43d8-9d3e-56e356becbb3'),
#  AIMessage(content="Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:40.539289Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1546293542, 'load_duration': 54790583, 'prompt_eval_count': 2003, 'prompt_eval_duration': 202114500, 'eval_count': 21, 'eval_duration': 1219624042, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--b726854a-29cc-4cf3-b1e8-0f9f4953e843-0', usage_metadata={'input_tokens': 2003, 'output_tokens': 21, 'total_tokens': 2024}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='977e366a-bc90-4de8-b713-624347a3c526'),
#  AIMessage(content="Great! Now that we have all our ingredients ready, let's start cooking!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:41.842922Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1293794292, 'load_duration': 41744750, 'prompt_eval_count': 2034, 'prompt_eval_duration': 202674750, 'eval_count': 17, 'eval_duration': 982275375, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--593207a0-a85f-403b-85f9-dca73da39229-0', usage_metadata={'input_tokens': 2034, 'output_tokens': 17, 'total_tokens': 2051}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='271ba0a8-0815-4e1f-aadb-bb7b340a45e6'),
#  AIMessage(content="STOP! You've completed the new recipe. Enjoy your meal!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:42.990249Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1121428750, 'load_duration': 51647375, 'prompt_eval_count': 2061, 'prompt_eval_duration': 203198250, 'eval_count': 14, 'eval_duration': 792787625, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--76e4eec6-6bdd-4cb8-b80c-16797cf1b21f-0', usage_metadata={'input_tokens': 2061, 'output_tokens': 14, 'total_tokens': 2075}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='7f31ece5-17d3-4747-8f45-87dd6ed024c4'),
#  AIMessage(content="That's it for now. If you need any more assistance or have other questions, feel free to ask.", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:44.692503Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1678481584, 'load_duration': 53912459, 'prompt_eval_count': 2085, 'prompt_eval_duration': 204019083, 'eval_count': 23, 'eval_duration': 1345403208, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--bf717d6e-723f-4e2b-b891-0b49d6fdf438-0', usage_metadata={'input_tokens': 2085, 'output_tokens': 23, 'total_tokens': 2108}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='05c976ed-bbea-4cc6-a89e-6c71d1f33ab6'),
#  AIMessage(content='Perfect! Have a great day and happy cooking!', additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:45.669832Z', 'done': True, 'done_reason': 'stop', 'total_duration': 951877125, 'load_duration': 52706416, 'prompt_eval_count': 2118, 'prompt_eval_duration': 204406417, 'eval_count': 11, 'eval_duration': 614834125, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--526a9b14-ea9c-4773-9a99-949b543933ec-0', usage_metadata={'input_tokens': 2118, 'output_tokens': 11, 'total_tokens': 2129}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='693b6130-6e79-40c5-b947-58411bef5b09'),
#  AIMessage(content="STOP! You've completed the recipe. Enjoy your meal!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:46.758864Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1069031958, 'load_duration': 50704667, 'prompt_eval_count': 2139, 'prompt_eval_duration': 203600041, 'eval_count': 13, 'eval_duration': 734938375, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--05e2a652-6a09-4c73-b272-a1e491bc664a-0', usage_metadata={'input_tokens': 2139, 'output_tokens': 13, 'total_tokens': 2152}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='555defd4-f263-40a2-ba90-80160e6d04a7'),
#  AIMessage(content='Great! If you have any other recipes or need assistance with anything else, feel free to ask.', additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:48.35671Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1571958417, 'load_duration': 52611209, 'prompt_eval_count': 2162, 'prompt_eval_duration': 203818708, 'eval_count': 21, 'eval_duration': 1231430584, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--f0bdaac8-f5fc-4e8c-aa54-9d04f96b118f-0', usage_metadata={'input_tokens': 2162, 'output_tokens': 21, 'total_tokens': 2183}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='09d92d8a-d525-4f87-949e-3c595e91e7ca'),
#  AIMessage(content="Perfect! Let's start a new recipe. What would you like to cook next?", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:49.782997Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1402242042, 'load_duration': 52527334, 'prompt_eval_count': 2193, 'prompt_eval_duration': 204624375, 'eval_count': 18, 'eval_duration': 1058886791, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--6acc176e-b91b-48ff-88c4-327eaf56ca3a-0', usage_metadata={'input_tokens': 2193, 'output_tokens': 18, 'total_tokens': 2211}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='103d7862-7e1a-4a08-ade4-8fdd2fed3f97'),
#  AIMessage(content="Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:51.565248Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1764341125, 'load_duration': 50508125, 'prompt_eval_count': 2221, 'prompt_eval_duration': 204807084, 'eval_count': 24, 'eval_duration': 1419293208, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--c9a20fdd-7767-4c23-8bbd-2cb27b4003c3-0', usage_metadata={'input_tokens': 2221, 'output_tokens': 24, 'total_tokens': 2245}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='1b5c7226-cdf3-471f-baf5-804b0057d466'),
#  AIMessage(content="I'm ready when you are!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:52.375573Z', 'done': True, 'done_reason': 'stop', 'total_duration': 785082291, 'load_duration': 55247333, 'prompt_eval_count': 2255, 'prompt_eval_duration': 204997583, 'eval_count': 8, 'eval_duration': 433663250, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--87aa3319-6b8f-427d-9b46-0d2164e3112d-0', usage_metadata={'input_tokens': 2255, 'output_tokens': 8, 'total_tokens': 2263}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='8d9ef1a5-d81f-48ee-9569-7eb45951a895'),
#  AIMessage(content="Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:53.962677Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1576122708, 'load_duration': 41382958, 'prompt_eval_count': 2273, 'prompt_eval_duration': 205050750, 'eval_count': 21, 'eval_duration': 1239403541, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--14d08e84-a026-4430-ba94-0a5ef2b149a1-0', usage_metadata={'input_tokens': 2273, 'output_tokens': 21, 'total_tokens': 2294}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='b2e3b89e-ed9e-4090-853d-7afa5bbfb137'),
#  AIMessage(content="Great! Now that we have all our ingredients ready, let's start cooking!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:55.345256Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1357183083, 'load_duration': 53525375, 'prompt_eval_count': 2304, 'prompt_eval_duration': 205231084, 'eval_count': 17, 'eval_duration': 999531125, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--f0833f4c-f22d-4a65-8136-543e5d6672fd-0', usage_metadata={'input_tokens': 2304, 'output_tokens': 17, 'total_tokens': 2321}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='e5a3b455-1df7-45bf-b3bd-de671a45348a'),
#  AIMessage(content="STOP! You've completed the new recipe. Enjoy your meal!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:56.544131Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1173128209, 'load_duration': 54203542, 'prompt_eval_count': 2331, 'prompt_eval_duration': 205481875, 'eval_count': 14, 'eval_duration': 812613292, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--7bdc50ee-3622-474d-8a34-de8060f7a728-0', usage_metadata={'input_tokens': 2331, 'output_tokens': 14, 'total_tokens': 2345}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='dad3b61b-2cd4-4add-baf1-85a7274c874d'),
#  AIMessage(content="That's it for now. If you need any more assistance or have other questions, feel free to ask.", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:58.311953Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1742695917, 'load_duration': 53846750, 'prompt_eval_count': 2355, 'prompt_eval_duration': 205712875, 'eval_count': 23, 'eval_duration': 1379777417, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--e4b9b27a-1af3-4973-a6c3-17984cd95edd-0', usage_metadata={'input_tokens': 2355, 'output_tokens': 23, 'total_tokens': 2378}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='7334b5c9-9c13-4d08-bc72-d36b8d8ee2bc'),
#  AIMessage(content='Perfect! Have a great day and happy cooking!', additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:22:59.306425Z', 'done': True, 'done_reason': 'stop', 'total_duration': 982592042, 'load_duration': 45204209, 'prompt_eval_count': 2388, 'prompt_eval_duration': 205915875, 'eval_count': 11, 'eval_duration': 627378917, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--302bd922-91fd-432f-9105-00e4a4f8daa7-0', usage_metadata={'input_tokens': 2388, 'output_tokens': 11, 'total_tokens': 2399}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='6b8f75e8-9b48-47b5-8198-4e2da02fc574'),
#  AIMessage(content="STOP! You've completed the recipe. Enjoy your meal!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:23:00.474729Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1139062625, 'load_duration': 62436208, 'prompt_eval_count': 2409, 'prompt_eval_duration': 207746000, 'eval_count': 13, 'eval_duration': 758733709, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--784565c4-309c-4fa1-80ea-3fda10ce9d92-0', usage_metadata={'input_tokens': 2409, 'output_tokens': 13, 'total_tokens': 2422}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='be160244-4418-4aa5-8765-e8ea1f7fd068'),
#  AIMessage(content='Great! If you have any other recipes or need assistance with anything else, feel free to ask.', additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:23:02.131159Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1635294584, 'load_duration': 49574959, 'prompt_eval_count': 2432, 'prompt_eval_duration': 206503125, 'eval_count': 21, 'eval_duration': 1265277292, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--8e3598d1-aa42-4af6-9e6f-bf11259ae855-0', usage_metadata={'input_tokens': 2432, 'output_tokens': 21, 'total_tokens': 2453}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='d66f3584-345a-4fdd-82ed-7fdf1fae84ac'),
#  AIMessage(content="Perfect! Let's start a new recipe. What would you like to cook next?", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:23:03.607352Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1449279458, 'load_duration': 54621000, 'prompt_eval_count': 2463, 'prompt_eval_duration': 207305292, 'eval_count': 18, 'eval_duration': 1071165291, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--cb74d560-fda5-4a22-bb8b-46ca51317fcf-0', usage_metadata={'input_tokens': 2463, 'output_tokens': 18, 'total_tokens': 2481}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='0c9d64c6-305c-4fe5-861f-d5eb8a50f4c5'),
# ...
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='45c1e8a6-bf88-433e-9b24-570a4d27a86e'),
#  AIMessage(content='Great! If you have any other recipes or need assistance with anything else, feel free to ask.', additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:31:18.864279Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4392997708, 'load_duration': 65900166, 'prompt_eval_count': 7832, 'prompt_eval_duration': 371319500, 'eval_count': 21, 'eval_duration': 1807758792, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--617db70a-a213-47e0-839f-c358d8d03ae9-0', usage_metadata={'input_tokens': 7832, 'output_tokens': 21, 'total_tokens': 7853}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='7588e222-6c01-4719-8a0d-8ba41d0db7b8'),
#  AIMessage(content="Perfect! Let's start a new recipe. What would you like to cook next?", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:31:23.095298Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4141920333, 'load_duration': 61761250, 'prompt_eval_count': 7863, 'prompt_eval_duration': 369839375, 'eval_count': 18, 'eval_duration': 1538792625, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--8582f41e-7c60-48bc-9861-e126399b4813-0', usage_metadata={'input_tokens': 7863, 'output_tokens': 18, 'total_tokens': 7881}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='3866a74e-215e-4844-8886-93f4f5ad3cb3'),
#  AIMessage(content="Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:31:27.844903Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4696260833, 'load_duration': 57852625, 'prompt_eval_count': 7891, 'prompt_eval_duration': 370976917, 'eval_count': 24, 'eval_duration': 2084245750, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--7d0a7fa4-cd70-4f30-9d5d-83a4e9787ecc-0', usage_metadata={'input_tokens': 7891, 'output_tokens': 24, 'total_tokens': 7915}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='5d3f187a-9b3a-4ce6-bbc8-14bd07525e5b'),
#  AIMessage(content="I'm ready when you are!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:31:31.178604Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3281479625, 'load_duration': 59616250, 'prompt_eval_count': 7925, 'prompt_eval_duration': 372411625, 'eval_count': 8, 'eval_duration': 636784375, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--537445e7-516c-452c-bdcd-0ba1b99a5b9a-0', usage_metadata={'input_tokens': 7925, 'output_tokens': 8, 'total_tokens': 7933}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='65bc1a08-887d-4d86-b8b5-83c814f452eb'),
#  AIMessage(content="Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:31:35.712507Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4481710000, 'load_duration': 56833959, 'prompt_eval_count': 7943, 'prompt_eval_duration': 363589625, 'eval_count': 21, 'eval_duration': 1819419500, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--6b5e6c75-e4d5-46fe-999f-ec1a54c5ffb3-0', usage_metadata={'input_tokens': 7943, 'output_tokens': 21, 'total_tokens': 7964}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='46c9f8d9-2dc0-4441-86e9-81602a30b09d'),
#  AIMessage(content="Great! Now that we have all our ingredients ready, let's start cooking!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:31:39.916983Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4149657000, 'load_duration': 58953958, 'prompt_eval_count': 7974, 'prompt_eval_duration': 373010125, 'eval_count': 17, 'eval_duration': 1457721375, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--d124267a-1bd4-46cc-9e52-e170f451ade5-0', usage_metadata={'input_tokens': 7974, 'output_tokens': 17, 'total_tokens': 7991}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='fbad23ea-1e9b-4adc-9356-d3f2000dab3d'),
#  AIMessage(content="STOP! You've completed the new recipe. Enjoy your meal!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:31:43.861072Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3894551208, 'load_duration': 58024625, 'prompt_eval_count': 8001, 'prompt_eval_duration': 376423792, 'eval_count': 14, 'eval_duration': 1185909833, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--dc64d10a-4bd5-42d6-a3c0-58ed0a838a73-0', usage_metadata={'input_tokens': 8001, 'output_tokens': 14, 'total_tokens': 8015}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='9f689ea7-a3ce-409a-8c40-ab37848a1b7a'),
#  AIMessage(content="That's it for now. If you need any more assistance or have other questions, feel free to ask.", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:31:48.718299Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4802897708, 'load_duration': 58765750, 'prompt_eval_count': 8025, 'prompt_eval_duration': 373180625, 'eval_count': 23, 'eval_duration': 2039191541, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--b394bd19-26b4-499a-afc5-046c19d0275b-0', usage_metadata={'input_tokens': 8025, 'output_tokens': 23, 'total_tokens': 8048}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='46cc5623-0a0a-4703-8e38-f527c1975549'),
#  AIMessage(content='Perfect! Have a great day and happy cooking!', additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:31:52.729061Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3814916417, 'load_duration': 102241334, 'prompt_eval_count': 8058, 'prompt_eval_duration': 397798500, 'eval_count': 11, 'eval_duration': 975615792, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--a303dc5a-5909-4ad4-b619-b09d28dde107-0', usage_metadata={'input_tokens': 8058, 'output_tokens': 11, 'total_tokens': 8069}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='dc41fe17-3447-49b2-8b5c-6dabd2e704cf'),
#  AIMessage(content="STOP! You've completed the recipe. Enjoy your meal!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:31:56.692025Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3905869625, 'load_duration': 59344333, 'prompt_eval_count': 8079, 'prompt_eval_duration': 384203292, 'eval_count': 13, 'eval_duration': 1139509750, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--b761b54c-2399-4b41-bce8-e772d7b97f73-0', usage_metadata={'input_tokens': 8079, 'output_tokens': 13, 'total_tokens': 8092}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='ce98c91f-7cc1-4bc1-8c50-0b43abf9badf'),
#  AIMessage(content='Great! If you have any other recipes or need assistance with anything else, feel free to ask.', additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:32:01.437325Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4690017750, 'load_duration': 62018334, 'prompt_eval_count': 8102, 'prompt_eval_duration': 385908625, 'eval_count': 21, 'eval_duration': 1901503500, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--a16663c3-16cc-4c34-b83c-0557f166476d-0', usage_metadata={'input_tokens': 8102, 'output_tokens': 21, 'total_tokens': 8123}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='0331f309-3bf7-47cf-9a11-d4f5408a7f4d'),
#  AIMessage(content="Perfect! Let's start a new recipe. What would you like to cook next?", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:32:05.919352Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4428499375, 'load_duration': 59765875, 'prompt_eval_count': 8133, 'prompt_eval_duration': 378494458, 'eval_count': 18, 'eval_duration': 1619559208, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--d2f4dcf1-5bf1-4a5d-803a-a8813c60013f-0', usage_metadata={'input_tokens': 8133, 'output_tokens': 18, 'total_tokens': 8151}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='0c1a4a1d-b2b5-420d-ada5-d2b84becb684'),
#  AIMessage(content="Let me know the ingredients and instructions for the new recipe, and I'll guide you through it step by step.", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:32:10.991165Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5018015250, 'load_duration': 59327584, 'prompt_eval_count': 8161, 'prompt_eval_duration': 383714625, 'eval_count': 24, 'eval_duration': 2189979708, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--697b09e3-9b8b-40ed-bd1d-f8b8a6ee4642-0', usage_metadata={'input_tokens': 8161, 'output_tokens': 24, 'total_tokens': 8185}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='fe43cdbe-5a61-4401-91cf-92e12f352804'),
#  AIMessage(content="I'm ready when you are!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:33:15.230132Z', 'done': True, 'done_reason': 'stop', 'total_duration': 64181177583, 'load_duration': 53638833, 'prompt_eval_count': 8189, 'prompt_eval_duration': 60877151709, 'eval_count': 8, 'eval_duration': 846671166, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--114d823b-f5b8-4dbb-925d-6956c5c3c3fe-0', usage_metadata={'input_tokens': 8189, 'output_tokens': 8, 'total_tokens': 8197}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='77ab3841-1787-4459-a78b-5aa98b017b8b'),
#  AIMessage(content="Perfect! Let's start with the preparation of the ingredients. What do we need to prepare first?", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:34:43.431126Z', 'done': True, 'done_reason': 'stop', 'total_duration': 88151143042, 'load_duration': 62314125, 'prompt_eval_count': 8184, 'prompt_eval_duration': 83024854833, 'eval_count': 21, 'eval_duration': 2635674792, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--babe8e57-2d1c-489a-9e36-595b1be1c726-0', usage_metadata={'input_tokens': 8184, 'output_tokens': 21, 'total_tokens': 8205}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='a3245994-b150-42ae-a711-7033c35fa705'),
#  AIMessage(content="Great! Now that we have all our ingredients ready, let's start cooking!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:36:06.382937Z', 'done': True, 'done_reason': 'stop', 'total_duration': 82889603459, 'load_duration': 63879792, 'prompt_eval_count': 8185, 'prompt_eval_duration': 78154286417, 'eval_count': 17, 'eval_duration': 2250799250, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--02976b59-b02a-4442-a1b7-273cbe1790d1-0', usage_metadata={'input_tokens': 8185, 'output_tokens': 17, 'total_tokens': 8202}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='19f07b62-cfe7-4d90-af81-feda53f58eeb'),
#  AIMessage(content="STOP! You've completed the new recipe. Enjoy your meal!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:37:31.299214Z', 'done': True, 'done_reason': 'stop', 'total_duration': 84859268209, 'load_duration': 63729084, 'prompt_eval_count': 8184, 'prompt_eval_duration': 80628201667, 'eval_count': 14, 'eval_duration': 1771090000, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--1ded1fbf-7414-4568-8a01-e1915f483e03-0', usage_metadata={'input_tokens': 8184, 'output_tokens': 14, 'total_tokens': 8198}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='dae58f20-d67e-4dd7-8809-9c09b20acbb5'),
#  AIMessage(content="That's it for now. If you need any more assistance or have other questions, feel free to ask.", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:38:56.98883Z', 'done': True, 'done_reason': 'stop', 'total_duration': 85623998833, 'load_duration': 72374625, 'prompt_eval_count': 8165, 'prompt_eval_duration': 79952465583, 'eval_count': 23, 'eval_duration': 3185979875, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--db15a776-ae32-4cf6-9ada-3dd62dc81b87-0', usage_metadata={'input_tokens': 8165, 'output_tokens': 23, 'total_tokens': 8188}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='073e2002-f566-4f52-8c16-3f85bebc71df'),
#  AIMessage(content='Perfect! Have a great day and happy cooking!', additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:40:19.200227Z', 'done': True, 'done_reason': 'stop', 'total_duration': 82149062250, 'load_duration': 64426750, 'prompt_eval_count': 8192, 'prompt_eval_duration': 78258293292, 'eval_count': 11, 'eval_duration': 1395309083, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--8a1b61f4-daa0-4b96-b5dd-18f4cb95dbf6-0', usage_metadata={'input_tokens': 8192, 'output_tokens': 11, 'total_tokens': 8203}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='86a07f8f-201c-4f5a-a599-700599a0ba17'),
#  AIMessage(content="STOP! You've completed the recipe. Enjoy your meal!", additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:41:46.439243Z', 'done': True, 'done_reason': 'stop', 'total_duration': 87175658875, 'load_duration': 65035709, 'prompt_eval_count': 8175, 'prompt_eval_duration': 82905388917, 'eval_count': 13, 'eval_duration': 1679935416, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--6912e4ab-2e67-42f1-ab9a-601e860f3e28-0', usage_metadata={'input_tokens': 8175, 'output_tokens': 13, 'total_tokens': 8188}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='633f4e69-d05d-4a10-b75f-2b154c264e67'),
#  AIMessage(content='Great! If you have any other recipes or need assistance with anything else, feel free to ask.', additional_kwargs={}, response_metadata={'model': 'llama3-groq-tool-use:8b', 'created_at': '2025-10-28T07:43:43.545676Z', 'done': True, 'done_reason': 'stop', 'total_duration': 67296529792, 'load_duration': 65447208, 'prompt_eval_count': 8192, 'prompt_eval_duration': 62848025667, 'eval_count': 21, 'eval_duration': 1938937708, 'model_name': 'llama3-groq-tool-use:8b', 'model_provider': 'ollama'}, id='lc_run--eb2367f9-f959-4586-a31a-240c5f1ab769-0', usage_metadata={'input_tokens': 8192, 'output_tokens': 21, 'total_tokens': 8213}),
#  HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='3fba28ce-1ffe-4ba8-a799-7d646457dee3')]
